# %%
import os

os.chdir("../..")

# %%
from src.dataset import get_cgc_df

pokemontcg_df = get_cgc_df()
pokemontcg_df.size
# Out:
# ['._1_4109677027', '0_4103461045', '1_4114875016', '._0_4056168001', '._1_4039323001']
# 0

# %%
pokemontcg_df.head()
# Out:
# Empty DataFrame
# Columns: [card_name, card_number, card_set, centering, cert_#, corners, edges, error_type, game, grade, language, surface, variant_1, year, variant_2, pedigree, grade_category, exists]
# Index: []

# %%
from src.dataset import get_pokemontcg_df, get_cgc_df, get_pokumon_df

pokemontcg_df, cgc_df, pokumon_df = get_pokemontcg_df(), get_cgc_df(), get_pokumon_df()
pokemontcg_df.size, cgc_df.size, pokumon_df.size
# Out:
# (10331, 481644, 115335)

# %%
pokemontcg_df.head()
# Out:
#                                            file_path
# 0  ./db/pokemontcg.io/sets-eng/ex-trainer-kit-200...
# 1  ./db/pokemontcg.io/sets-eng/ex-trainer-kit-200...
# 2  ./db/pokemontcg.io/sets-eng/ex-trainer-kit-200...
# 3  ./db/pokemontcg.io/sets-eng/ex-trainer-kit-200...
# 4  ./db/pokemontcg.io/sets-eng/ex-trainer-kit-200...

# %%
cgc_df.head()
# Out:
#                   card_name card_number                      card_set  \
# key
# 4101425001        Blastoise       4/165                    Expedition
# 4045819001  Mewtwo & Mew GX       SM191             Black Star Promos
# 4069976001     Metal Energy      97/115              EX Unseen Forces
# 4069976002         Entei EX     103/108                Dark Explorers
# 4052775001        Charizard       4/102  Celebrations - Classic Coll.
#
#            centering      cert_#  corners  edges      error_type     game  \
# key
# 4101425001       9.5  4101425001      7.0    7.5  Additional Ink  Pokémon
# 4045819001       NaN  4045819001      NaN    NaN             NaN  Pokémon
# 4069976001       8.5  4069976001      7.5    8.5             NaN  Pokémon
# 4069976002       8.5  4069976002      7.5    7.0             NaN  Pokémon
# 4052775001       NaN  4052775001      NaN    NaN             NaN  Pokémon
#
#            grade language  surface               variant_1  year variant_2  \
# key
# ...

# %%
pokumon_df.head()
# Out:
#                                                             artist  \
# id
# %ce%b4-rainbow-energy-149-pcg-p-japanese-promo      Takumi Akabane
# %ce%b4-rainbow-energy-9-17-pokemon-organized-pl...  Takumi Akabane
# 1st-place-rare-candy-welcome-festa-2017-sm-p          Toyste Beach
# 20-damage-from-confusion-expansion-sheet-3-1998...   Nobuyuki Habu
# 2nd-place-rare-candy-welcome-festa-2017-sm-p          Toyste Beach
#
#                                                      card_type  \
# id
# %ce%b4-rainbow-energy-149-pcg-p-japanese-promo          Energy
# %ce%b4-rainbow-energy-9-17-pokemon-organized-pl...      Energy
# 1st-place-rare-candy-welcome-festa-2017-sm-p           Trainer
# 20-damage-from-confusion-expansion-sheet-3-1998...  Extra Rule
# 2nd-place-rare-candy-welcome-festa-2017-sm-p           Trainer
#
#                                                                     cardname  \
# id
# %ce%b4-rainbow-energy-149-pcg-p-japanese-promo              δ Rainbow Energy
# ...

# %%
sorted(cgc_df["card_set"].unique())
# Out:
# ['10th Movie Commemoration Set',
#  '11th Movie Commemoration',
#  '25th Anniv. Golden Box',
#  '25th Anniversary Collection',
#  '25th Anniversary Promo Pack',
#  '25th Anniversary Promo Pk.',
#  'ADV-P Promo Cards',
#  'ANA Promo',
#  'Advent of Arceus',
#  'All Stars Collection: Set B',
#  'Alter Genesis',
#  'Amazing Volt Tackle',
#  'Ancient Origins',
#  'Aquapolis',
#  'Arceus',
#  'Art Academy Contest',
#  'Ash vs T. Rocket Deck Kit',
#  'Astral Radiance',
#  'Awakening Legends',
#  'BREAKpoint',
#  'BREAKthrough',
#  'Bandit Ring',
#  'Base Expansion Pack',
#  'Base Set',
#  'Base Set - 1st Edition',
#  'Base Set - Shadowless',
#  'Base Set - Unlimited',
#  'Base Set 2',
#  'Battle Academy',
#  'Battle Region',
#  'Battle Road Promos',
#  'Battle Styles',
#  'Beat of the Frontier',
#  'Best of Game Promos',
#  'Best of XY',
#  'Black & White',
#  'Black & White Promos',
#  'Black Deck Kit',
#  'Black Star Promos',
#  'Blastoise VMAX Starter Set',
#  'Blue Sky Stream',
# ...

# %%
cgc_df[cgc_df["card_set"] == "Vending Series 3"]
# Out:
#                                 card_name card_number          card_set  \
# key
# 4108223004                      Growlithe         NaN  Vending Series 3
# 4108223005                        Kadabra         NaN  Vending Series 3
# 4108223006                         Tauros         NaN  Vending Series 3
# 4108223007                         Tauros         NaN  Vending Series 3
# 4108223008                      Sandslash         NaN  Vending Series 3
# 4108223009                       Graveler         NaN  Vending Series 3
# 4108223010                     Bellsprout         NaN  Vending Series 3
# 4108223011                          Hypno         NaN  Vending Series 3
# 4108223016                        Machoke         NaN  Vending Series 3
# 4108223017                         Rhydon         NaN  Vending Series 3
# 3923506001                          Lose?         NaN  Vending Series 3
# 4045583002                Pokémon Machine         NaN  Vending Series 3
# ...

# %%
cgc_df["card_set"].describe()
# Out:
# count                 26758
# unique                  367
# top       Black Star Promos
# freq                   1959
# Name: card_set, dtype: object

# %%
cgc_df["card_name"].describe()
# Out:
# count         26758
# unique         1922
# top       Charizard
# freq           1497
# Name: card_name, dtype: object

# %%
pokumon_df[pokumon_df["promo_set"] == "PCG-P"][pokumon_df["card_type"] == "Energy"]
# Out:
# /var/folders/x_/mr86sn6n2jd09sz6rz6z8dk00000gn/T/ipykernel_46841/1788357297.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pokumon_df[pokumon_df["promo_set"] == "PCG-P"][pokumon_df["card_type"] == "Energy"]
#                                                         artist card_type  \
# id
# %ce%b4-rainbow-energy-149-pcg-p-japanese-promo  Takumi Akabane    Energy
# dark-metal-energy-054-pcg-p-japanese-promo      Takumi Akabane    Energy
# fighting-energy-060-pcg-p-japanese-promo                  None    Energy
# fire-energy-056-pcg-p-japanese-promo                      None    Energy
# grass-energy-055-pcg-p-japanese-promo                     None    Energy
# heal-energy-022-pcg-p-japanese-promo            Takumi Akabane    Energy
# holon-energy-ff-115-pcg-p-japanese-promo        Takumi Akabane    Energy
# holon-energy-gl-114-pcg-p-japanese-promo        Takumi Akabane    Energy
# ...
